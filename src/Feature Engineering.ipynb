# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pylab as plt

# %% [markdown]
# ## Feature Engieering

# %%
df = df.groupby('Vehicle Body Type').filter(lambda x: len(x) > 700)

#Vehicle Body 1 SUV
SUVs = ['SUBN', 'UT', 'SW', 'WAGO', 'SU', 'LL', 'WG', 'SV']

for i in SUVs: 
    df['Vehicle Body Type'].replace({i:1}, inplace = True)
    
#Vehicle Body 2 SEDAN    
SEDAN = ['4DSD', 'SDN', '2DSD', 'SD', '4D', '4 DR', 
         'CONV', '4S', 'PV', 'CP', 'SEDN', 'ST', '2 DR','2D'
        'CV', 'SEDA', 'FOUR' '4W', '4H', '4DSE', 
        'FODO', '2S', 'CON', '4DOO', 'FOUR', '4W', '2D']

for i in SEDAN: 
    df['Vehicle Body Type'].replace({i:2}, inplace = True)

df['Vehicle Body Type'].replace({'CV':2}, inplace = True)

#Vehicle Body 3 Van 
Van = ['VAN', 'DELV','VN', 'Van']
for i in Van: 
    df['Vehicle Body Type'].replace({i:3}, inplace = True)


#Vehicle Body 4 Truck 
Trucks = ['TOW', 'DELV', 'PICK', 'REFG', 'UTIL', 
          'TK', 'PK', 'FLAT', 'PU', 'TR/C', 'PKUP', 'TRK', 
         'SEMI', 'STAK', 'Truc', "TRUC", 'Carg', 'T/CR', 'TRAC', 'P-U']
for i in Trucks: 
    df['Vehicle Body Type'].replace({i:4}, inplace = True)

#Vehicle Body 5 Bike
Bikes = ['MCY', "MP", 'MOPD', 'MC', ]
for i in Bikes: 
    df['Vehicle Body Type'].replace({i:5}, inplace = True)

#Vehicle Body 6 Trailers
Hang = ['TRLR', 'TRL', 'TRAI', 'TANK', 'TLR']


for i in Hang: 
    df['Vehicle Body Type'].replace({i:6}, inplace = True)

    
#Vehicle Body 7 Publically Utilized Transit 
Public = ['TAXI', 'BUS', 'DUMP', ]

for i in Public: 
    df['Vehicle Body Type'].replace({i:7}, inplace = True)

#Vehicle Body 8 Misc
MISC = ['BOAT', '5D', 'HB', 'CG', 'MOBL', 'H/WH', 'APUR']
for i in MISC: 
    df['Vehicle Body Type'].replace({i:8}, inplace = True)
    
df["Vehicle Body Type"].value_counts()
# Out:
# 1    4560546
# 2    3903811
# 3    1650778
# 4     601250
# 7      73119
# 5      68449
# 6      43809
# 8      22886
# Name: Vehicle Body Type, dtype: int64

# %%
df = df.groupby('Vehicle Make').filter(lambda x: len(x) > 700)

#1 japan 
japan = ['HONDA', 'TOYOT','NISSA', 'LEXUS', 'ACURA', 
         'INFIN', 'SUBAR', 'MAZDA', 'HIN', 'ISUZU', 'MITSU',
        'SUZUK', 'UD', 'YAMAH', 'SCION', 'KAWAS', 'Nissa', 'Toyot', 'Honda']

for i in japan: 
    df['Vehicle Make'].replace({i:1}, inplace = True)

#2 usa 
usa = ['FORD', 'CHEVR', 'JEEP', 'FRUEH', 'DODGE', 
       'GMC', 'INTER', 'CHRYS', 'CADIL', 'LINCO', 'WORKH', 
       'BUICK', 'KENW', 'TESLA', 'MERCU', 'PETER', 'SATUR', 'PONTI', 
      "MACK", 'HARLE', 'HUMME', 'OLDSM', 'Chevr', 'FORD', 
       'THOMA', 'STERL', 'FONTA', 'STARC', 'TRAIL', 'PLYMO', 'TRAC', 'Dodge']

for i in usa: 
    df['Vehicle Make'].replace({i:2}, inplace = True)

#3 germany 
germany = ['ME/BE', 'BMW', 'VOLKS', 'AUDI', 'PORSC', 'NIU', 'SMART']

for i in germany: 
    df['Vehicle Make'].replace({i:3}, inplace = True)

#4 italy
italy = ['FIAT', 'MASE', 'ALFAR', 'VESPA', 'TRIUM', 'DUCAT', 'LAMBO']

for i in italy: 
    df['Vehicle Make'].replace({i:4}, inplace = True)
    
#5 korea
korea = ['HYUND', 'KIA', 'HYUN', 'GENES']
for i in korea: 
    df['Vehicle Make'].replace({i:5}, inplace = True)

#6 uk
uk = ['ROVER', 'MINI', 'JAGUA', 'BENTL']
for i in uk: 
    df['Vehicle Make'].replace({i:6}, inplace = True)

#7 sweden
sweden = ['VOLVO', 'SAAB']
for i in sweden: 
    df['Vehicle Make'].replace({i:7}, inplace = True)

#8 canada
canada = ['MCI', 'PREVO']
for i in canada: 
    df['Vehicle Color'].replace({i:8}, inplace = True)

#other
df['Vehicle Make'].replace({'KENWO':2, 'Ford':2, 'IC':2, 'Gener':2}, inplace = True)
df['Vehicle Make'].replace({'MCI': 8, 'PREVO':8}, inplace = True)
df['Vehicle Make'].replace({'GREAT': 9, 'VANHO':9, 'NS':9, 'NS/OT':9, 'UTILI':9, 'SPRI':9}, inplace = True)
df['Vehicle Make'].value_counts()
# Out:
# 1    4775777
# 2    3837992
# 3    1396754
# 5     489834
# 6     149276
# 7      89908
# 9      88440
# 4      31796
# 8       2917
# Name: Vehicle Make, dtype: int64

# %%
df = df.groupby('Vehicle Color').filter(lambda x: len(x) > 500)
#1 = grey 
Grey = ['GY', 'GR', 'GREY', 'SILVE', 'GL', 'GRY', 'GRAY', 'SIL','GY.', 'LTGY', 
       'LTG', 'LT/', 'SL.', 'SL', 'DKGY', 'GYGY', 'DKG', 'BKGY', 
        'WHGY', 'SILV', 'BLGY', 'G', 'GY/', 'GRAY.', 'GRY.', 
        'GYGR', 'RDGY', 'LTGR', 'GREY.']

for i in Grey: 
    df['Vehicle Color'].replace({i:1}, inplace = True)
    
#2 purple 
purple = ['PR', 'PURPL', 'LAVEN', 'NOCL']

for i in purple: 
    df['Vehicle Color'].replace({i:2}, inplace = True)
    
#3 while 
White = ['WH', 'WHITE', 'WHI', 'WHT', 'WT', 'WT.', 'W', 'WG.', 'WH/', 'WHT.']
for i in White:
    df['Vehicle Color'].replace({i:3}, inplace = True)

df['Vehicle Color'].replace({"WH.":3}, inplace = True)

#4 Black 
Black = ['BK', 'BLACK', 'BLK', 'BK.', 'DK/', 'BLK.']
for i in Black: 
    df['Vehicle Color'].replace({i:4}, inplace = True)

#5 red
red = ['RD','RED', 'MR', 'RD.', 'RED.', 'DKRD', 'MAR', 'MAROO', 'DKR', 'RDW']
for i in red: 
    df['Vehicle Color'].replace({i:5}, inplace = True)

#6 brown
brown = ['BROWN', 'BR', 'BRO', 'BRN', 'BN', 'BRW' ]
for i in brown: 
    df['Vehicle Color'].replace({i:6}, inplace = True)

#7 orange
orange = ['OR', 'ORANG']
for i in orange: 
    df['Vehicle Color'].replace({i:7}, inplace = True)

#8 blue
blue = ['BLUE', 'BLU', 'B', 'DKB', 'BLUE.', 'LTBL', 'BL.', 
        'WHBL', 'DKBL', 'BKBL', 'GYBL', 'LTB', 'BLW', 'WHB']
for i in blue: 
    df['Vehicle Color'].replace({i:8}, inplace = True)

df['Vehicle Color'].replace({"BL":8}, inplace = True)

#9 yellow
yellow = ['YW', 'YELLO', 'GOLD', 'GLD', 'YEL', 'YELL']
for i in yellow: 
    df['Vehicle Color'].replace({i:9}, inplace = True)

#10 green
green = ['GN', 'GRN', 'GN ', 'GN.', 'DKGR']
for i in green: 
    df['Vehicle Color'].replace({i:10}, inplace = True)
    
df['Vehicle Color'].replace({"GREEN":10}, inplace = True)

#11 tan
tan = ['TN', 'TAN', 'BGE']
for i in tan: 
    df['Vehicle Color'].replace({i:11}, inplace = True)

#12 misc 
MISC = ['UNKNO', 'OTHER', 'UNK', 'NOC']
for i in MISC: 
    df['Vehicle Color'].replace({i:12}, inplace = True)

df['Vehicle Color'].value_counts()
# Out:
# 3     2920205
# 1     2893506
# 4     2368015
# 8      887734
# 5      594968
# 6      321986
# 11     117767
# 9      113333
# 12      59820
# 10      54191
# 7       32577
# 2       11399
# Name: Vehicle Color, dtype: int64

# %%
#1
northeast = ['CT', 'ME', 'NH', 'RI', 'VT', 'NJ', 'NY', 'PA', 'MA']
for i in northeast: 
    df['Registration State'].replace({i:1}, inplace = True)


#2
midwest = ['IL', 'IN', 'MI', 'OH', 'WI', 'IA', 'KS', 'MO', 'NE', 'ND', 'SD', 'MN']
for i in midwest: 
    df['Registration State'].replace({i:2}, inplace = True)

#3
south = ['DE', 'FL', 'GA', 'MD', 'NC', 'SC', 'DC', 
         'WV', 'AL', 'KY', 'MS', 'TN', 'AR', 'LA','OK', 'TX', 'VA']

for i in south: 
    df['Registration State'].replace({i:3}, inplace = True)
    
#4
west = ["AZ", 'CO', 'ID', 'MT', 'NV', 'NM', 'UT', 'WY', 'AK', 
       'CA', 'HI', 'OR', 'WA']

for i in west: 
    df['Registration State'].replace({i:4}, inplace = True)
    

    
#5 

international = ['ON', 'QB', 'PR','AB', 'BC', 'NS', 'FO','NB', 'MB', 'PE', 'SK', 'MX', 'YT']
for i in international: 
    df['Registration State'].replace({i:5}, inplace = True)
    
#6 government plates 

gov = ['GV', 'DP']
for i in gov: 
     df['Registration State'].replace({i:6}, inplace = True)

# %%
df['Registration State'].value_counts()
# Out:
# 1     9535053
# 3      538795
# 2      198424
# 4       68415
# 6       15413
# 99      13198
# 5        6203
# Name: Registration State, dtype: int64

# %%
#1
emergency = ['AMB', 'CME', 'MED', 'VAS', 'SNO']
for i in emergency:
     df['Plate Type'].replace({i:1}, inplace = True)

#2
military = ['ARG', 'AYG', 'NLM', 'STG']
for i in military:
     df['Plate Type'].replace({i:2}, inplace = True)
                               
#3
veteran = ['CMH', 'FPW', 'JWV', 'MCL', 'PHS', 'PPH', 'SOS', 'GSM']
for i in veteran:
     df['Plate Type'].replace({i:3}, inplace = True)
                               
#4
government = ['CBS', 'CCK', 'CLG', 'GAC', 'GSC', 'JCA', 'JCL', 'JSC', 
              'NYA', 'NYC', 'NYS', 'PSD', 'SRN', 'STA', 'SUP', 'USC', 'USS', 'EDU']
for i in government:
     df['Plate Type'].replace({i:4}, inplace = True)                               
#5
ag = ['AGR', 'FAR', 'TRC', 'AGC']
for i in ag:
     df['Plate Type'].replace({i:5}, inplace = True)                               

#6
motorcycle = ['LMA', 'LMB', 'LMC', 'MOT', 'HSM']
for i in motorcycle:
     df['Plate Type'].replace({i:6}, inplace = True)

#7
civ = ['PAS', 'OMS', 'RGL', 'SRF', 'HIS', 'ATV', 'ORG', 'LUA']
for i in civ:
     df['Plate Type'].replace({i:7}, inplace = True)

#8
dealer = ['ATD', 'MCD', 'DLR']
for i in dealer:
     df['Plate Type'].replace({i:8}, inplace = True)

#9
commercial = ['CHC', 'COM', 'CSP', 'ORC', 'RGC', 'SPC', 'SEM']
for i in commercial:
     df['Plate Type'].replace({i:9}, inplace = True)

#10
trailer = ['LTR', 'HOU']
for i in trailer:
     df['Plate Type'].replace({i:10}, inplace = True)
        
#11 public 

public = ['OMO', 'OMR', 'ORM', 'OMT', 'OMV', 'OML', 'OMF', 'VPL', 'SCL']
for i in public:
     df['Plate Type'].replace({i:11}, inplace = True)
        
#12 
sports = ['BOB', 'SPO', 'WUG']
for i in sports:
     df['Plate Type'].replace({i:12}, inplace = True)

#13 
ex_NYC = ['CMB', 'IRP', 'ITP']
for i in ex_NYC:
     df['Plate Type'].replace({i:13}, inplace = True)

#14 
misc = ['HAC', 'HAM', 'GFC', 'BOT', 'LOC']
for i in misc:
     df['Plate Type'].replace({i:14}, inplace = True)

#15 
carrier = ['TOW', 'TRA', 'THC', 'TRL', 'HIF', 'HIR']
for i in carrier:
     df['Plate Type'].replace({i:15}, inplace = True)
        
#16 
unknown = ['APP', '999']
for i in unknown: 
    df['Plate Type'].replace({i:16}, inplace = True)

# %%
df['Plate Type'].value_counts()
# Out:
# 7     8327391
# 9     1399376
# 11     411608
# 16     101202
# 6       48351
# 13      18083
# 1       18082
# 12      13938
# 5       13271
# 4       11420
# 15       8803
# 8        2013
# 3        1327
# 2         477
# 14        147
# 10         12
# Name: Plate Type, dtype: int64

# %%
#MAKE DIFFERENT BUCKETS FOR COMPETING GROUPS 


#Diplomat
df["Violation Code"].replace({28:100, 64:100, 65:100, 81:100}, inplace = True)

#Bus
df["Violation Code"].replace({1:200, 2:200, 3:200, 4:200, 5:200, 29:200, 79:200, 77:200}, inplace = True)

#Moving Violation 
df["Violation Code"].replace({7:300, 8:300, 12:300, 36:300}, inplace = True)

#No Parking
df["Violation Code"].replace({20:400, 21:400, 24:400, 63:400, 27:400}, inplace = True)

#Trailer 
df["Violation Code"].replace({6:500, 66:500}, inplace = True)

#Blocking 
df["Violation Code"].replace({9:600, 45:600, 49:600, 98:600, 54:600, 40:600, 67:600}, inplace = True)

#Credentials 
df["Violation Code"].replace({70:700, 71:700, 72:700, 73:700, 74:700, 75:700, 76:700, 83:700, 87:700, 33:700}, inplace = True)

#Commerical Violations  
df["Violation Code"].replace({78:800, 82:800, 84:800, 59:800, 85:800, 88:800}, inplace = True)

#Metered Violations  
df["Violation Code"].replace({32:900, 34:900, 37:900, 38:900, 31:900, 42:900, 39:900, 69:900, 44:900, 43:900}, inplace = True)

#Geographic Violations   
df["Violation Code"].replace({86:1000, 89:1000, 47:1000, 58:1000, 57:1000}, inplace = True)

#Taxi 
df["Violation Code"].replace({13:1100, 22:1100, 23:1100}, inplace = True)

#Credentials 
df["Violation Code"].replace({10:1200, 14:1200, 15:1200, 17:1200, 16:1200, 18:1200, 19:1200, 25:1200, 26:1200, 30:1200, 11:1200}, inplace = True)


#Highway 
df["Violation Code"].replace({55:1300, 56:1300}, inplace = True)
    

#Proximity Parking  
df["Violation Code"].replace({51:1400, 52:1400, 50:1400, 46:1400, 48:1400, 53:1400, 60:1400, 62:1400, 97:1400, 96:1400, 61:1400, 68:1400}, inplace = True)


#Equipment 
df["Violation Code"].replace({80:1500, 93:1500, 92:1500}, inplace = True)


#Commerce 
df["Violation Code"].replace({35:1600, 91:1600, 90:1600}, inplace = True)

#Other 
df["Violation Code"].replace({41:1700, 99:1700, 94:1700}, inplace = True)

#drop values not in data dictionary 0,95
df = df[df["Violation Code"] != 95]
df = df[df["Violation Code"] != 0]

# %%
new_year = []
for i in df['Vehicle Year']:
    if i == 0:
        new_year.append(np.nan)
    else:
        new_year.append(i)
        
df['Vehicle Year'] = new_year

# %%
#create categorical variable for ease of use 
df["Range"] = df["From Hours In Effect"] + df["To Hours In Effect"]

range_array = []
for i in df['Range']:
    try:
        i = str(i)
        if i[:3] == "ALL":
            range_array.append("ALL")
        elif (i[4] == 'A') & (i[-1] == 'A'):
            i = i[0:2] +":" +i[2:4] + "AM - " + i[5:7] +":" +i[7:9] + "AM"
            range_array.append(i)

        elif (i[4] == 'A') & (i[-1] == 'P'):
            i = i[0:2] +":" +i[2:4] + "AM - " + i[5:7] +":" +i[7:9] + "PM"
            range_array.append(i)

        elif (i[4] == 'P') & (i[-1] == 'A'):
            i = i[0:2] +":" +i[2:4] + "PM - " + i[5:7] +":" +i[7:9] + "AM"
            range_array.append(i)


        elif (i[4] == 'P') & (i[-1] == 'P'):
            i = i[0:2] +":" +i[2:4] + "PM - " + i[5:7] +":" +i[7:9] + "PM"
            range_array.append(i)

        else:
            range_array.append(np.nan)
    except: 
        range_array.append(np.nan)

df['Range'] = range_array

new_dropped = ["From Hours In Effect", "To Hours In Effect"]
df = df.drop(new_dropped, axis = 1)

# %%
#Vehicle Expiration Date 
expiration_array = []
for i in df['Vehicle Expiration Date']: 
    if i == 0: 
        expiration_array.append(np.nan)
    elif i != 0:
        i = str(i)
        i = i[:4] + "-" + i[4:6] + '-' + i[6:]
        expiration_array.append(i)
    else:
        expiration_array(np.nan)

df['Vehicle Expiration Date']  = expiration_array
df['Vehicle Expiration Date'] = pd.to_datetime(df['Vehicle Expiration Date'], format = '%Y-%m-%d', errors = 'ignore')

# %%
pd.set_option('display.max_columns', 500)
df.head()
# Out:
#    Unnamed: 0  Summons Number  Plate ID Registration State  Plate Type  \
# 0     8778924      8760192677   37222MM                  1           9
# 1     2028567      8702745926   JAK2471                  1           7
# 2     4137399      4668603510    603180                  1           7
# 3     5917949      8728844683    XGKW92                  1           7
# 4     9388021      4013156477  T700579C                  1          11
#
#                Issue Date  Violation Code  Vehicle Body Type  Vehicle Make  \
# 0  02/05/2020 12:00:00 AM             900                  3             2
# 1  08/15/2019 12:00:00 AM             700                  1             1
# 2  10/04/2019 12:00:00 AM             300                  2             1
# 3  11/18/2019 12:00:00 AM             900                  3             1
# 4  02/20/2020 12:00:00 AM             200                  2             5
#
#   Issuing Agency  Street Code1  Street Code2  Street Code3  \
# ...

# %%
#check percentage of missing data for columns 
df.isna().mean().round(4) * 100
# Out:
# Unnamed: 0                             0.00
# Summons Number                         0.00
# Plate ID                               0.00
# Registration State                     0.00
# Plate Type                             0.00
# Issue Date                             0.00
# Violation Code                         0.00
# Vehicle Body Type                      0.00
# Vehicle Make                           0.00
# Issuing Agency                         0.00
# Street Code1                           0.00
# Street Code2                           0.00
# Street Code3                           0.00
# Vehicle Expiration Date               33.62
# Violation Location                    32.38
# Violation Precinct                     0.00
# Issuer Precinct                        0.00
# Issuer Code                            0.00
# Issuer Command                        32.12
# Issuer Squad                          32.42
# Violation Time                         0.00
# ...

# %%
#remove based off percentage missing  - 90% and above
remove_na = ["Time First Observed", "Meter Number", "Unregistered Vehicle?", "No Standing or Stopping Violation", "Hydrant Violation", "Double Parking Violation"]
df = df.drop(remove_na, axis = 1)

# %%
df = df.drop('Unnamed: 0', axis = 1) 
df.shape
# Out:
# (10374754, 37)

# %%
#drop values if county code is missing 
df = df[df['Violation County'].notna()]

# %%
df = df[((df['House Number'].notna())&(df['Street Name'].notna()))]

# %% [markdown]
# ## Checkpoint, before we remove extraneous info

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pylab as plt

# %%
df = pd.read_csv("Clean Part One.csv")
# Out:
# C:\Users\hcho1\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df['Violation Code'].value_counts()
# Out:
# 400     1818122
# 900     1486729
# 1200    1351175
# 700      805628
# 1400     614182
# 600      575172
# 800      124405
# 1000      83626
# 1100      24748
# 500       19068
# 100       10550
# 200        8930
# 1700       2193
# 1500       1538
# 300        1168
# 1600        752
# 1300        316
# Name: Violation Code, dtype: int64

# %%
#Getting Rid of Columns that do not have data that pertains to our analysis 

remove_extr = ["Street Code1", 'Street Code2', 'Street Code3', 'Violation Location', 'Issuer Precinct', 
               'Issuer Code', 'Issuer Command', 'Issuer Squad', 'Law Section', 'Violation Legal Code',
               'Days Parking In Effect', 'Violation Post Code', 'Violation Description', 'Date First Observed', 'Violation Precinct']

df = df.drop(remove_extr, axis = 1)

# %%
#In front
df["Violation In Front Of Or Opposite"].replace({'F':1, "I":1, "R":1}, inplace = True)

#Opposite
df["Violation In Front Of Or Opposite"].replace({"O":2}, inplace = True)
df["Violation In Front Of Or Opposite"].value_counts()
# Out:
# 1.0    5272994
# 2.0    1648858
# Name: Violation In Front Of Or Opposite, dtype: int64

# %%
df.head()
# Out:
#    Summons Number Plate ID  Registration State  Plate Type  \
# 0      8760192677  37222MM                   1           9
# 1      8702745926  JAK2471                   1           7
# 2      8728844683   XGKW92                   1           7
# 3      8778101189  79351JZ                   1           9
# 4      8751971010  31410MG                   1           9
#
#                Issue Date  Violation Code  Vehicle Body Type  Vehicle Make  \
# 0  02/05/2020 12:00:00 AM             900                  3             2
# 1  08/15/2019 12:00:00 AM             700                  1             1
# 2  11/18/2019 12:00:00 AM             900                  3             1
# 3  11/08/2019 12:00:00 AM             900                  3             2
# 4  08/16/2019 12:00:00 AM             400                  3             2
#
#   Issuing Agency Vehicle Expiration Date  ...  \
# 0              T              2020-11-30  ...
# 1              T              2020-06-12  ...
# ...

# %%
pd.options.display.max_rows = 2000

# %%
df['Sub Division'].value_counts()
# Out:
# D1    1129116
# C      663657
# I4     551007
# D      538810
# H1     529249
# E2     493827
# F1     348513
# J6     312530
# I3     286443
# J3     209296
# C3     207060
# K2     195336
# J2     163998
# d1     103013
# C4      96217
# h1      80027
# L2      70059
# E5      67605
# E9      61071
# L3      59110
# K7      55994
# B       47395
# c       44615
# j6      40587
# e2      39192
# E3      38694
# d       37700
# F6      35164
# F4      30504
# F2      27157
# K6      26761
# K1      22119
# H0      18268
# K4      17817
# C1      16844
# j3      15808
# J7      15526
# A1      15162
# j2      14515
# c3      14168
# k2      13717
# l3      12947
# f1      10795
# J5      10418
# M1      10047
# C8       9989
# K5       8097
# O3       7869
# E1       6391
# C5       6366
# c4       6296
# M5       5847
# C2       5817
# l2       5802
# e5       5204
# k7       3653
# e9       3647
# M2       3517
# b        3432
# J4       3215
# F7       2888
# e3       2717
# ...

# %%
import re 
letters = re.compile(r'[A-Z]')

division_array = []

for j in df['Sub Division']:
    j = str(j)
    j = j.upper()
    if letters.search(j):
        division_array.append(j[0])
    else:
        division_array.append("unknown")
        

df['Sub Division']  = division_array
df['Sub Division'].value_counts()
# Out:
# D          1814270
# C          1074719
# I           838327
# J           791816
# E           720029
# H           628309
# F           460133
# K           348531
# L           149792
# B            50827
# M            21137
# A            16136
# O             8412
# unknown       2508
# N             2194
# P             1125
# G               37
# Name: Sub Division, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Issue Date']).dt.date
df['Time'] = pd.to_datetime(df['Issue Date']).dt.time
df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month
df['Day'] = pd.to_datetime(df['Date']).dt.day

# %%
df.head()
# Out:
#    Summons Number Plate ID  Registration State  Plate Type  Violation Code  \
# 0      8760192677  37222MM                   1           9             900
# 1      8702745926  JAK2471                   1           7             700
# 2      8728844683   XGKW92                   1           7             900
# 3      8778101189  79351JZ                   1           9             900
# 4      8751971010  31410MG                   1           9             400
#
#    Vehicle Body Type  Vehicle Make Issuing Agency Vehicle Expiration Date  \
# 0                  3             2              T              2020-11-30
# 1                  1             1              T              2020-06-12
# 2                  3             1              T              8888-00-88
# 3                  3             2              T              2021-06-30
# 4                  3             2              T              8888-00-88
#
#   Violation Time  ...  Sub Division  Vehicle Color Vehicle Year  \
# ...

# %%
df['Vehicle Expiration Date'] = pd.to_datetime(df["Vehicle Expiration Date"], errors = 'coerce')
df
# Out:
#          Summons Number Plate ID  Registration State  Plate Type  \
# 0            8760192677  37222MM                   1           9
# 1            8702745926  JAK2471                   1           7
# 2            8728844683   XGKW92                   1           7
# 3            8778101189  79351JZ                   1           9
# 4            8751971010  31410MG                   1           9
# ...                 ...      ...                 ...         ...
# 6928297      8843424210  ETT7044                   1           7
# 6928298      8815028687  GGY6367                   1           7
# 6928299      8978154220  JPN2703                   1           7
# 6928300      8660684564   SEPT22                   1           7
# 6928301      8914760881  KJC4090                   1           7
#
#          Violation Code  Vehicle Body Type  Vehicle Make Issuing Agency  \
# 0                   900                  3             2              T
# ...

# %%
new_column = []
for i in df['Violation Time']:
    i = str(i)
    if i[-1] == 'P':
        i = i[0:2] +":" +i[2:4] + " " +i[-1]+"M"
        new_column.append(i)

    elif (i[-1] == 'A'):
        i = i[0:2] +":" +i[2:4] + " " +i[-1]+"M"
        new_column.append(i)
    
    else:
        new_column.append(np.nan)
        
df['Violation Time'] = new_column
        
df = df.groupby('Violation Time').filter(lambda x: len(x) > 2)

# %%
df['index'] = range(1,len(df)+1)

# %%
# Out:
#   File "C:\Users\hcho1\AppData\Local\Temp/ipykernel_27484/1951995059.py", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
remove_ids= ["Summons Number", "Plate ID"]
df = df.drop(remove_ids, axis = 1)

# %%
pd.set_option('display.max_columns', 500)
df
# Out:
#          Registration State  Plate Type  Violation Code  Vehicle Body Type  \
# 0                         1           9             900                  3
# 1                         1           7             700                  1
# 2                         1           7             900                  3
# 3                         1           9             900                  3
# 4                         1           9             400                  3
# ...                     ...         ...             ...                ...
# 6928297                   1           7             900                  2
# 6928298                   1           7             900                  1
# 6928299                   1           7            1400                  2
# 6928300                   1           7             400                  2
# 6928301                   1           7            1200                  1
#
# ...

# %%
for i, j in enumerate()

# %%
df.to_csv("Cleaned Data - Final.csv")

# %%
df2 = pd.read_csv("Cleaned Data - Final.csv")

# %%
df2
# Out:
#          Unnamed: 0  Registration State  Plate Type  Violation Code  \
# 0                 0                   1           9             900
# 1                 1                   1           7             700
# 2                 2                   1           7             900
# 3                 3                   1           9             900
# 4                 4                   1           9             400
# ...             ...                 ...         ...             ...
# 6928073     6928297                   1           7             900
# 6928074     6928298                   1           7             900
# 6928075     6928299                   1           7            1400
# 6928076     6928300                   1           7             400
# 6928077     6928301                   1           7            1200
#
#          Vehicle Body Type  Vehicle Make Issuing Agency  \
# 0                        3             2              T
# ...

# %%
np.random.seed(42)

df3 = df2.sample(10**6)

# %%
#df3 = df3.drop("Unnamed: 0", axis = 1) 
#df3
df3.to_csv('FINAL SUBSET.csv', index=False)

# %%
df3 = pd.read_csv('FINAL SUBSET.csv')

# %%
integer_array =[]

for i in df3['Violation County']:
    integer_array.append(int(i))
    
df3['Violation County'] = integer_array

# %%
first_order = ['House Number', 'Street Name', 'Violation County', 'Intersecting Street']

df3 = df3[[c for c in df3 if c not in first_order]+ first_order]

# %%
df_sub1 = df3.iloc[0:(df3.shape[0]//4),:]
df_sub2 = df3.iloc[df3.shape[0]//4:(2*(df3.shape[0]//4)),:]

# %%
#df_sub1.columns = df_sub1.columns.str.replace(" ", "_")


df_sub1
# Out:
#         Registration State  Plate Type  Violation Code  Vehicle Body Type  \
# 0                        1           9             900                  3
# 1                        1           7            1200                  2
# 2                        1           9             400                  3
# 3                        1           7            1200                  1
# 4                        1           7             400                  2
# ...                    ...         ...             ...                ...
# 249995                   3           7             600                  2
# 249996                   1           7             400                  4
# 249997                   1           7            1400                  2
# 249998                   1           7             900                  1
# 249999                   1           9             400                  3
#
#         Vehicle Make Issuing Agency Vehicle Expiration Date Violation Time  \
# ...

# %%
df_sub2.columns = df_sub2.columns.str.replace(" ", "_")
#df_sub2 = df_sub2.drop("Unnamed:_0", axis = 1) 

df_sub2
# Out:
#         Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 250000                   1           9             900                  3
# 250001                   1           7            1200                  1
# 250002                   1           7             700                  1
# 250003                   1           7            1200                  2
# 250004                   1           7             900                  2
# ...                    ...         ...             ...                ...
# 499995                   1           9             400                  3
# 499996                   1           7             400                  2
# 499997                   1           7            1000                  3
# 499998                   1           7             700                  2
# 499999                   1           9             400                  3
#
#         Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...

# %%
df_sub3 = df3.iloc[(2*(df3.shape[0]//4)):(3*(df3.shape[0]//4)),:]
df_sub4 = df3.iloc[(3*(df3.shape[0]//4)):(4*(df3.shape[0]//4)),:]

# %%
df_sub3.columns = df_sub3.columns.str.replace(" ", "_")


df_sub3
# Out:
#         Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 500000                   1           9            1400                  3
# 500001                   1           7            1200                  1
# 500002                   1           9            1200                  3
# 500003                   1           7             900                  1
# 500004                   1           7             400                  1
# ...                    ...         ...             ...                ...
# 749995                   1           7             700                  1
# 749996                   1           7             900                  1
# 749997                   6           7             600                  3
# 749998                   1           7             400                  1
# 749999                   3           7            1400                  1
#
#         Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...

# %%
df_sub4.columns = df_sub4.columns.str.replace(" ", "_")

df_sub4
# Out:
#         Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 750000                   1           7             900                  2
# 750001                   1           7            1200                  2
# 750002                   1           7            1200                  1
# 750003                   1          11             400                  1
# 750004                   1           7            1400                  1
# ...                    ...         ...             ...                ...
# 999995                   1           7             700                  2
# 999996                   1           9            1400                  3
# 999997                   1           7             600                  2
# 999998                   1           9             900                  3
# 999999                   1           7            1200                  1
#
#         Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...

# %%
df_testing = df_sub4.iloc[0:10**4,:]

# %%
df_sub1.to_csv("Subset 1 - Final.csv", index=False)
df_sub2.to_csv("Subset 2 - Final.csv", index = False)
df_sub3.to_csv("Subset 3 - Final.csv", index= False)
df_sub4.to_csv("Subset 4 - Final.csv", index=False)

# %%
df_testing.to_csv("Testing - Final.csv", index = False)

# %%
df_testing
# Out:
#         Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 750000                   1           7             900                  2
# 750001                   1           7            1200                  2
# 750002                   1           7            1200                  1
# 750003                   1          11             400                  1
# 750004                   1           7            1400                  1
# ...                    ...         ...             ...                ...
# 759995                   1           7             400                  4
# 759996                   1          11             400                  1
# 759997                   1           7             400                  1
# 759998                   1           7            1200                  1
# 759999                   1           7             400                  2
#
#         Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...

# %%
first = pd.read_csv("Subset 1 - Final.csv")
for i, j in enumerate(first.columns):
    print(i,j)
# Out:
# 0 Registration State
# 1 Plate Type
# 2 Violation Code
# 3 Vehicle Body Type
# 4 Vehicle Make
# 5 Issuing Agency
# 6 Vehicle Expiration Date
# 7 Violation Time
# 8 Violation In Front Of Or Opposite
# 9 Sub Division
# 10 Vehicle Color
# 11 Vehicle Year
# 12 Feet From Curb
# 13 Year Set
# 14 Range
# 15 Date
# 16 Year
# 17 Month
# 18 Day
# 19 index
# 20 House Number
# 21 Street Name
# 22 Violation County
# 23 Intersecting Street

# %%
secoond = pd.read_csv("Subset 2 - Final.csv")
for i, j in enumerate(secoond.columns):
    print(i,j)
# Out:
# 0 Registration_State
# 1 Plate_Type
# 2 Violation_Code
# 3 Vehicle_Body_Type
# 4 Vehicle_Make
# 5 Issuing_Agency
# 6 Vehicle_Expiration_Date
# 7 Violation_Time
# 8 Violation_In_Front_Of_Or_Opposite
# 9 Sub_Division
# 10 Vehicle_Color
# 11 Vehicle_Year
# 12 Feet_From_Curb
# 13 Year_Set
# 14 Range
# 15 Date
# 16 Year
# 17 Month
# 18 Day
# 19 index
# 20 House_Number
# 21 Street_Name
# 22 Violation_County
# 23 Intersecting_Street

# %%
import pandas as pd
Third = pd.read_csv("Subset 3 - Final.csv")
for i, j in enumerate(Third.columns):
    print(i,j)
# Out:
# 0 Registration_State
# 1 Plate_Type
# 2 Violation_Code
# 3 Vehicle_Body_Type
# 4 Vehicle_Make
# 5 Issuing_Agency
# 6 Vehicle_Expiration_Date
# 7 Violation_Time
# 8 Violation_In_Front_Of_Or_Opposite
# 9 Sub_Division
# 10 Vehicle_Color
# 11 Vehicle_Year
# 12 Feet_From_Curb
# 13 Year_Set
# 14 Range
# 15 Date
# 16 Year
# 17 Month
# 18 Day
# 19 index
# 20 House_Number
# 21 Street_Name
# 22 Violation_County
# 23 Intersecting_Street

# %%
Fourth = pd.read_csv("Subset 4 - Final.csv")
for i, j in enumerate(Fourth.columns):
    print(i,j)
# Out:
# 0 Registration_State
# 1 Plate_Type
# 2 Violation_Code
# 3 Vehicle_Body_Type
# 4 Vehicle_Make
# 5 Issuing_Agency
# 6 Vehicle_Expiration_Date
# 7 Violation_Time
# 8 Violation_In_Front_Of_Or_Opposite
# 9 Sub_Division
# 10 Vehicle_Color
# 11 Vehicle_Year
# 12 Feet_From_Curb
# 13 Year_Set
# 14 Range
# 15 Date
# 16 Year
# 17 Month
# 18 Day
# 19 index
# 20 House_Number
# 21 Street_Name
# 22 Violation_County
# 23 Intersecting_Street

# %%
Fourth
# Out:
#         Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 0                        1           7             900                  2
# 1                        1           7            1200                  2
# 2                        1           7            1200                  1
# 3                        1          11             400                  1
# 4                        1           7            1400                  1
# ...                    ...         ...             ...                ...
# 249995                   1           7             700                  2
# 249996                   1           9            1400                  3
# 249997                   1           7             600                  2
# 249998                   1           9             900                  3
# 249999                   1           7            1200                  1
#
#         Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...

# %%
f = pd.read_csv("Testing - Final.csv")
for i, j in enumerate(f.columns):
    print(i,j)
# Out:
# 0 Registration_State
# 1 Plate_Type
# 2 Violation_Code
# 3 Vehicle_Body_Type
# 4 Vehicle_Make
# 5 Issuing_Agency
# 6 Vehicle_Expiration_Date
# 7 Violation_Time
# 8 Violation_In_Front_Of_Or_Opposite
# 9 Sub_Division
# 10 Vehicle_Color
# 11 Vehicle_Year
# 12 Feet_From_Curb
# 13 Year_Set
# 14 Range
# 15 Date
# 16 Year
# 17 Month
# 18 Day
# 19 index
# 20 House_Number
# 21 Street_Name
# 22 Violation_County
# 23 Intersecting_Street

# %%
f
# Out:
#       Registration_State  Plate_Type  Violation_Code  Vehicle_Body_Type  \
# 0                      1           7             900                  2
# 1                      1           7            1200                  2
# 2                      1           7            1200                  1
# 3                      1          11             400                  1
# 4                      1           7            1400                  1
# ...                  ...         ...             ...                ...
# 9995                   1           7             400                  4
# 9996                   1          11             400                  1
# 9997                   1           7             400                  1
# 9998                   1           7            1200                  1
# 9999                   1           7             400                  2
#
#       Vehicle_Make Issuing_Agency Vehicle_Expiration_Date Violation_Time  \
# ...
